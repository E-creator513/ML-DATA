# %% [markdown]
# #  WALLET TRUST SCORE (DATA) ANALYSIS

# %%
import pandas as pd
import glob
import os


folder_path = "/content/drive/MyDrive/blockchain/"

# folder existsance
if not os.path.exists(folder_path):
    raise FileNotFoundError(f"The folder {folder_path} does not exist")

# CSV files in the blockchain folder
all_files = glob.glob(os.path.join(folder_path, "*.xls*")) + \
            glob.glob(os.path.join(folder_path, "*.csv"))

if not all_files:
    available_files = os.listdir(folder_path)
    raise FileNotFoundError(
        f"No Excel or CSV files found in {folder_path}\n"
        f"Available files: {available_files}"
    )

print(f"Found {len(all_files)} files to merge:")
for f in all_files:
    print(f" - {os.path.basename(f)}")

#  file BASED on extensions
dfs = []
for f in all_files:
    try:
        if f.endswith('.csv'):
            dfs.append(pd.read_csv(f))
        else:  # .xls, .xlsx
            dfs.append(pd.read_excel(f))
    except Exception as e:
        print(f"Error reading {f}: {str(e)}")
        continue

if not dfs:
    raise ValueError("No files were successfully read")


df = pd.concat(dfs, ignore_index=True)

# merged data
output_path = os.path.join(folder_path, "merged_wallet_data.csv")
df.to_csv(output_path, index=False)
print(f"\nSuccessfully merged {len(dfs)} files into {output_path}")
print(f"Final DataFrame shape: {df.shape}")
# Out:
# Found 24 files to merge:
#  - export-transaction-list-1744110485753.csv
#  - export-transaction-list-1744110499789.csv
#  - export-transaction-list-1744110506833.csv
#  - export-transaction-list-1744110516373.csv
#  - export-transaction-list-1744110559075.csv
#  - export-transaction-list-1744110565390.csv
#  - export-transaction-list-1744110618418.csv
#  - export-transaction-list-1744110623329.csv
#  - export-transaction-list-1744110630161.csv
#  - export-transaction-list-1744110636267.csv
#  - export-transaction-list-1744110641210.csv
#  - export-transaction-list-1744110647377.csv
#  - export-transaction-list-1744110736862.csv
#  - export-transaction-list-1744110740778.csv
#  - export-transaction-list-1744110743543.csv
#  - export-transaction-list-1744110746341.csv
#  - export-transaction-list-1744110750625.csv
#  - export-transaction-list-1744110753840.csv
#  - export-transaction-list-1744110759307.csv
#  - export-transaction-list-1744110809883.csv
#  - wallet_risk_score_20250623_112430.csv
#  - merged_wallet_data.csv
#  - cleaned_wallet_data.csv
#  - wallet_risk_scores.csv
# /tmp/ipython-input-4119163453.py:32: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs.append(pd.read_csv(f))
# Successfully merged 24 files into /content/drive/MyDrive/blockchain/merged_wallet_data.csv
# Final DataFrame shape: (3072020, 22)

# %% [markdown]
# # **Feature Engineering (Key Risk Signals)**

# %%
import pandas as pd
import numpy as np


df = pd.read_csv("/content/drive/MyDrive/blockchain/merged_wallet_data.csv")

def clean_currency(column):
    return (
        column.astype(str)
        .str.extract(r'([\d,.]+)')[0]
        .str.replace(',', '', regex=False)
        .replace('', np.nan)
        .astype(float)
    )



# cleaning
df['Value (USD)'] = clean_currency(df['Value (USD)'])
df['Txn Fee'] = clean_currency(df['Txn Fee'])

# cleaned data
df.to_csv("/content/drive/MyDrive/blockchain/cleaned_wallet_data.csv", index=False)
print("Successfully cleaned and saved!")
# Out:
# /tmp/ipython-input-838411771.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/blockchain/merged_wallet_data.csv")
# Successfully cleaned and saved!

# %% [markdown]
# # **EDA**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#cleaned dataset
df = pd.read_csv("/content/drive/MyDrive/blockchain/cleaned_wallet_data.csv")

# Info & schema
print("=== Data Overview ===")
print(df.info())
print("\n=== Summary Statistics ===")
print(df.describe(include='all').T)

# Missing values
print("\n=== Missing Values ===")
missing = df.isnull().sum().sort_values(ascending=False)
print(missing)

# Unique values per column
print("\n=== Unique Value Counts ===")
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")



# Transaction value distribution
plt.figure(figsize=(10, 5))
sns.histplot(df['Value (USD)'].dropna(), bins=50, kde=True)
plt.title("Transaction Value Distribution (USD)")
plt.xlabel("Value (USD)")
plt.ylabel("Frequency")
plt.show()

# Transaction fee distribution
plt.figure(figsize=(10, 5))
sns.histplot(df['Txn Fee'].dropna(), bins=50, kde=True, color="orange")
plt.title("Transaction Fee Distribution (USD)")
plt.xlabel("Fee (USD)")
plt.ylabel("Frequency")
plt.show()

# Boxplot for outliers in transaction values
plt.figure(figsize=(10, 4))
sns.boxplot(x=df['Value (USD)'])
plt.title("Boxplot – Transaction Values")
plt.show()



# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# Scatterplot: value vs fee
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Value (USD)', y='Txn Fee', data=df, alpha=0.6)
plt.title("Transaction Value vs Fee")
plt.xlabel("Value (USD)")
plt.ylabel("Fee (USD)")
plt.show()



# If you have a column like "Wallet Address" or "Txn Type"
if 'Wallet Address' in df.columns:
    top_wallets = df.groupby('Wallet Address')['Value (USD)'].sum().nlargest(10)
    plt.figure(figsize=(10, 6))
    sns.barplot(x=top_wallets.values, y=top_wallets.index)
    plt.title("Top 10 Wallets by Total Transaction Value")
    plt.xlabel("Total Value (USD)")
    plt.ylabel("Wallet Address")
    plt.show()
# Out:
# === Data Overview ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3072020 entries, 0 to 3072019
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Transaction Hash      object
#  1   Status                object
#  2   Method                object
#  3   Blockno               float64
#  4   DateTime (UTC)        object
#  5   From                  object
#  6   From_Nametag          object
#  7   To                    object
#  8   To_Nametag            object
#  9   Amount                object
#  10  Value (USD)           float64
#  11  Txn Fee               float64
#  12  total_tx              float64
#  13  avg_value_usd         float64
#  14  total_volume_usd      float64
#  15  avg_gas               float64
#  16  unique_to             float64
#  17  interacted_with_scam  float64
#  18  recency_days          float64
#  19  gas_ratio             float64
#  20  risk_score            float64
#  21  high_gas_user         float64
# dtypes: float64(13), object(9)
# memory usage: 515.6+ MB
# None
#
# === Summary Statistics ===
#                           count unique  \
# Transaction Hash        3070000   1351
# Status                  3070000      4
# Method                  3070000    182
# Blockno               3070000.0    NaN
# DateTime (UTC)          3070000      9
# From                    3072020   1103
# From_Nametag             526505    122
# To                      3063860    617
# To_Nametag              1877305    175
# Amount                  3070000    582
# Value (USD)           3070000.0    NaN
# Txn Fee               3070000.0    NaN
# total_tx                 2020.0    NaN
# avg_value_usd            2020.0    NaN
# total_volume_usd         2020.0    NaN
# avg_gas                   110.0    NaN
# unique_to                 110.0    NaN
# interacted_with_scam     2020.0    NaN
# recency_days              110.0    NaN
# gas_ratio                 110.0    NaN
# risk_score               2020.0    NaN
# high_gas_user            1910.0    NaN
#
#                                                                     top  \
# Transaction Hash      0xe622734c4e7ab59d60c79454364164ed8ba6a9edf10f...
# Status                                                          Success
# Method                                                         Transfer
# Blockno                                                             NaN
# DateTime (UTC)                                      2025-04-08 11:09:11
# From                         0x7a93539c1bf9a96f87044925deb7a0849266213e
# From_Nametag                                               Crypto.com 2
# To                           0xdac17f958d2ee523a2206206994597c13d831ec7
# To_Nametag                                      Tether: USDT Stablecoin
# Amount                                                            0 ETH
# Value (USD)                                                         NaN
# Txn Fee                                                             NaN
# total_tx                                                            NaN
# avg_value_usd                                                       NaN
# total_volume_usd                                                    NaN
# avg_gas                                                             NaN
# unique_to                                                           NaN
# interacted_with_scam                                                NaN
# recency_days                                                        NaN
# gas_ratio                                                           NaN
# risk_score                                                          NaN
# high_gas_user                                                       NaN
#
#                          freq            mean              std         min  \
# Transaction Hash         6140             NaN              NaN         NaN
# Status                3037765             NaN              NaN         NaN
# Method                1998570             NaN              NaN         NaN
# Blockno                   NaN    22223788.511         4.145586  22223778.0
# DateTime (UTC)         821225             NaN              NaN         NaN
# From                    76750             NaN              NaN         NaN
# From_Nametag            53725             NaN              NaN         NaN
# To                     423660             NaN              NaN         NaN
# To_Nametag             423660             NaN              NaN         NaN
# Amount                1584120             NaN              NaN         NaN
# Value (USD)               NaN      789.296095      8549.021869         0.0
# Txn Fee                   NaN        2.705826         2.819992      0.0001
# total_tx                  NaN      132.168812       421.055584         7.0
# avg_value_usd             NaN    11755.210592     35376.441957         0.0
# total_volume_usd          NaN  1119926.990208  12024656.909673         0.0
# avg_gas                   NaN        2.915306         2.223772    0.000174
# unique_to                 NaN             1.5         0.809916         1.0
# interacted_with_scam      NaN             0.0              0.0         0.0
# recency_days              NaN            76.0              0.0        76.0
# gas_ratio                 NaN          0.0112         0.017086         0.0
# risk_score                NaN           100.0              0.0       100.0
# high_gas_user             NaN             0.0              0.0         0.0
#
#                              25%         50%         75%          max
# Transaction Hash             NaN         NaN         NaN          NaN
# Status                       NaN         NaN         NaN          NaN
# Method                       NaN         NaN         NaN          NaN
# Blockno               22223787.0  22223788.0  22223792.0   22223794.0
# DateTime (UTC)               NaN         NaN         NaN          NaN
# From                         NaN         NaN         NaN          NaN
# From_Nametag                 NaN         NaN         NaN          NaN
# To                           NaN         NaN         NaN          NaN
# To_Nametag                   NaN         NaN         NaN          NaN
# Amount                       NaN         NaN         NaN          NaN
# Value (USD)                  0.0         0.0     74.3575    169645.29
# Txn Fee                  0.00095       1.879     4.27325         9.99
# total_tx                    21.0        42.0        98.0      10738.0
# avg_value_usd             2.6725  182.516667     1429.75     133865.9
# total_volume_usd         1357.63      7665.7    73059.56  410700581.2
# avg_gas                    1.005    3.100359       5.187        6.684
# unique_to                    1.0         1.0         2.0          3.0
# interacted_with_scam         0.0         0.0         0.0          0.0
# recency_days                76.0        76.0        76.0         76.0
# gas_ratio               0.000001    0.001538    0.018507     0.056891
# risk_score                 100.0       100.0       100.0        100.0
# high_gas_user                0.0         0.0         0.0          0.0
#
# === Missing Values ===
# gas_ratio               3071910
# recency_days            3071910
# avg_gas                 3071910
# unique_to               3071910
# high_gas_user           3070110
# total_tx                3070000
# interacted_with_scam    3070000
# risk_score              3070000
# total_volume_usd        3070000
# avg_value_usd           3070000
# From_Nametag            2545515
# To_Nametag              1194715
# To                         8160
# Transaction Hash           2020
# Status                     2020
# DateTime (UTC)             2020
# Blockno                    2020
# Method                     2020
# Amount                     2020
# Value (USD)                2020
# Txn Fee                    2020
# From                          0
# dtype: int64
#
# === Unique Value Counts ===
# Transaction Hash: 1351 unique values
# Status: 4 unique values
# Method: 182 unique values
# Blockno: 9 unique values
# DateTime (UTC): 9 unique values
# From: 1103 unique values
# From_Nametag: 122 unique values
# To: 617 unique values
# To_Nametag: 175 unique values
# Amount: 582 unique values
# Value (USD): 445 unique values
# Txn Fee: 825 unique values
# total_tx: 42 unique values
# avg_value_usd: 27 unique values
# total_volume_usd: 62 unique values
# avg_gas: 10 unique values
# unique_to: 3 unique values
# interacted_with_scam: 1 unique values
# recency_days: 1 unique values
# gas_ratio: 10 unique values
# risk_score: 1 unique values
# high_gas_user: 1 unique values

# %% [markdown]
# # VISUALISATION

# %%
# ================== Visual Summary ==================

# 1. Distribution of Transaction Values & Fees (Side by Side)
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
sns.histplot(df['Value (USD)'].dropna(), bins=50, kde=True, color='skyblue')
plt.title("Transaction Value Distribution")
plt.xlabel("Value (USD)")

plt.subplot(1,2,2)
sns.histplot(df['Txn Fee'].dropna(), bins=50, kde=True, color='orange')
plt.title("Transaction Fee Distribution")
plt.xlabel("Fee (USD)")

plt.tight_layout()
plt.show()

# 2. Boxplots for Transaction Values & Fees
plt.figure(figsize=(14,4))
plt.subplot(1,2,1)
sns.boxplot(x=df['Value (USD)'], color='skyblue')
plt.title("Boxplot – Transaction Values")

plt.subplot(1,2,2)
sns.boxplot(x=df['Txn Fee'], color='orange')
plt.title("Boxplot – Transaction Fees")

plt.tight_layout()
plt.show()

# 3. Correlation Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# 4. Value vs Fee Scatterplot
plt.figure(figsize=(8,5))
sns.scatterplot(x='Value (USD)', y='Txn Fee', data=df, alpha=0.6)
plt.title("Transaction Value vs Fee")
plt.xlabel("Value (USD)")
plt.ylabel("Fee (USD)")
plt.show()

# 5. Top Wallets by Transaction Value (if column exists)
if 'Wallet Address' in df.columns:
    top_wallets = df.groupby('Wallet Address')['Value (USD)'].sum().nlargest(10)
    plt.figure(figsize=(10,6))
    sns.barplot(x=top_wallets.values, y=top_wallets.index, palette='viridis')
    plt.title("Top 10 Wallets by Total Transaction Value")
    plt.xlabel("Total Value (USD)")
    plt.ylabel("Wallet Address")
    plt.show()

# %%
import pandas as pd

# Load merged data
df = pd.read_csv("/content/drive/MyDrive/blockchain/cleaned_wallet_data.csv")

# Create risk features
features = df.groupby('From').agg(
    total_tx=('Transaction Hash', 'count'),
    avg_value_usd=('Value (USD)', 'mean'),
    total_volume_usd=('Value (USD)', 'sum'),
    interacted_with_scam=('To_Nametag', lambda x: x.str.contains('scam|phish', case=False, na=False).any().astype(int)),
    high_gas_user=('Txn Fee', lambda x: (x > x.quantile(0.9)).any().astype(int))
).reset_index()

# %% [markdown]
# # Risk Scoring Model (XGBoost - Even Without Labels)

# %%
from xgboost import XGBClassifier
import numpy as np

# If you HAVE scam labels (supervised):
model = XGBClassifier().fit(features[['total_tx', 'avg_value_usd', 'total_volume_usd']], features['interacted_with_scam'])

# If NO labels (unsupervised anomaly detection):
from sklearn.ensemble import IsolationForest
features['risk_score'] = IsolationForest(contamination=0.1).fit_predict(features[['total_tx', 'total_volume_usd']])
features['risk_score'] = (features['risk_score'] == -1).astype(int)  # -1 = anomaly

# %%
# Normalize score 0-100
features['risk_score'] = features['risk_score'] * 100  # Simple binary for now

# Top 10 Riskiest Wallets
risky_wallets = features.sort_values('risk_score', ascending=False).head(10)

# Save results
risky_wallets.to_csv('/content/drive/MyDrive/blockchain/wallet_risk_scores.csv', index=False)

# %%
import seaborn as sns
sns.scatterplot(data=features, x='total_volume_usd', y='risk_score', hue='interacted_with_scam')

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
from xgboost import XGBClassifier
from datetime import datetime

def clean_currency(column):
    return (
        column.astype(str)
        .str.extract(r"([\d,.]+)")[0]
        .str.replace(",", "", regex=False)
        .replace("", np.nan)
        .astype(float)
    )

def engineer_wallet_features(df: pd.DataFrame) -> pd.DataFrame:
    df['Value (USD)'] = clean_currency(df['Value (USD)'])
    df['Txn Fee'] = clean_currency(df['Txn Fee'])
    df['DateTime (UTC)'] = pd.to_datetime(df['DateTime (UTC)'], errors='coerce')
    grouped = df.groupby('From')
    features = grouped.agg(
        total_tx=('Transaction Hash', 'count'),
        avg_value_usd=('Value (USD)', 'mean'),
        total_volume_usd=('Value (USD)', 'sum'),
        avg_gas=('Txn Fee', 'mean'),
        unique_to=('To', pd.Series.nunique),
        last_seen=('DateTime (UTC)', 'max'),
        interacted_with_scam=('To_Nametag', lambda x: x.str.contains('scam|phish', case=False, na=False).any().astype(int)),
    ).reset_index()
    now = pd.Timestamp.now()
    features['recency_days'] = (now - features['last_seen']).dt.days
    features['gas_ratio'] = features['avg_gas'] / features['avg_value_usd'].replace(0, np.nan)
    features = features.drop(columns='last_seen')
    return features.fillna(0)

def score_unsupervised(features: pd.DataFrame) -> pd.DataFrame:
    model = IsolationForest(contamination=0.1, random_state=42)
    X = features[['total_tx', 'avg_value_usd', 'total_volume_usd', 'recency_days']]
    scores = model.fit(X).decision_function(X)
    scores_normalized = (scores - scores.min()) / (scores.max() - scores.min())
    features['risk_score'] = (1 - scores_normalized) * 100
    return features

# %%
df = pd.read_csv("/content/drive/MyDrive/blockchain/cleaned_wallet_data.csv")
features = engineer_wallet_features(df)
scored = score_unsupervised(features)

# %%
import pandas as pd
import numpy as np

# Load data
df = pd.read_csv("/content/drive/MyDrive/blockchain/merged_wallet_data.csv")

def clean_currency(column):
    return (
        column.astype(str)
        .str.extract(r'([\d,.]+)')[0]
        .str.replace(',', '', regex=False)
        .replace('', np.nan)
        .astype(float)
    )



# Apply cleaning
df['Value (USD)'] = clean_currency(df['Value (USD)'])
df['Txn Fee'] = clean_currency(df['Txn Fee'])

# Save cleaned data
df.to_csv("/content/drive/MyDrive/blockchain/cleaned_wallet_data.csv", index=False)
print("Successfully cleaned and saved!")
# Out:
# /tmp/ipython-input-838411771.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/blockchain/merged_wallet_data.csv")
# Successfully cleaned and saved!

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Summary stats
print("Total wallets analyzed:", len(scored))
print("Wallets flagged risky (score ≥ 80):", (scored['risk_score'] >= 80).sum())
print("Average risk score:", round(scored['risk_score'].mean(), 2))

# Top 10 risky wallets
top_10 = scored.sort_values("risk_score", ascending=False).head(10)
sns.barplot(data=top_10, x="risk_score", y="From", palette="Reds_r")
plt.title("Top 10 Risky Wallets")
plt.show()

# Risk score distribution
sns.histplot(scored["risk_score"], bins=20, kde=True, color="purple")
plt.title("Risk Score Distribution")
plt.show()

# Total volume vs risk score
sns.scatterplot(data=scored, x="total_volume_usd", y="risk_score", hue="interacted_with_scam")
plt.xscale("log")
plt.title("Total Volume vs Risk Score")
plt.show()

# Transaction count vs risk score heatmap
sns.kdeplot(data=scored, x="total_tx", y="risk_score", fill=True, cmap="magma")
plt.title("Tx Count vs Risk Score Density")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3523220292.py in <cell line: 0>()
#       3
#       4 # Summary stats
# ----> 5 print("Total wallets analyzed:", len(scored))
#       6 print("Wallets flagged risky (score ≥ 80):", (scored['risk_score'] >= 80).sum())
#       7 print("Average risk score:", round(scored['risk_score'].mean(), 2))
#
# NameError: name 'scored' is not defined

# %% [markdown]
# # Second-degree counterparty count to feature engineer.
#
# Training XGB and plug in SHAP to produce a summary plot.

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
from xgboost import XGBClassifier
from datetime import datetime
import networkx as nx


def clean_currency(column):
    return (
        column.astype(str)
        .str.extract(r"([\d,.]+)")[0]
        .str.replace(",", "", regex=False)
        .replace("", np.nan)
        .astype(float)
    )


def engineer_wallet_features(df: pd.DataFrame) -> pd.DataFrame:
    df['Value (USD)'] = clean_currency(df['Value (USD)'])
    df['Txn Fee'] = clean_currency(df['Txn Fee'])
    df['DateTime (UTC)'] = pd.to_datetime(df['DateTime (UTC)'], errors='coerce')

    # Build graph for second-degree connections
    G = nx.from_pandas_edgelist(df, source='From', target='To', create_using=nx.DiGraph())
    second_degree_counts = {node: len(set(nx.descendants(G, node))) for node in df['From'].unique()}

    grouped = df.groupby('From')
    features = grouped.agg(
        total_tx=('Transaction Hash', 'count'),
        avg_value_usd=('Value (USD)', 'mean'),
        total_volume_usd=('Value (USD)', 'sum'),
        avg_gas=('Txn Fee', 'mean'),
        unique_to=('To', pd.Series.nunique),
        last_seen=('DateTime (UTC)', 'max'),
        interacted_with_scam=('To_Nametag', lambda x: x.str.contains('scam|phish', case=False, na=False).any().astype(int)),
    ).reset_index()

    features['second_degree_count'] = features['From'].map(second_degree_counts)

    now = pd.Timestamp.now()
    features['recency_days'] = (now - features['last_seen']).dt.days
    features['gas_ratio'] = features['avg_gas'] / features['avg_value_usd'].replace(0, np.nan)
    features = features.drop(columns='last_seen')

    return features.fillna(0)


def score_unsupervised(features: pd.DataFrame) -> pd.DataFrame:
    model = IsolationForest(contamination=0.1, random_state=42)
    X = features[['total_tx', 'avg_value_usd', 'total_volume_usd', 'recency_days', 'second_degree_count']]
    scores = model.fit(X).decision_function(X)
    scores_normalized = (scores - scores.min()) / (scores.max() - scores.min())
    features['risk_score'] = (1 - scores_normalized) * 100
    return features


def score_supervised(features: pd.DataFrame) -> pd.DataFrame:
    model = XGBClassifier()
    X = features[['total_tx', 'avg_value_usd', 'total_volume_usd', 'recency_days', 'second_degree_count']]
    y = features['interacted_with_scam']
    model.fit(X, y)
    features['risk_score'] = model.predict_proba(X)[:, 1] * 100
    return features


def save_top_risky(features: pd.DataFrame, out_path="wallet_risk_scores.csv", top_n=10):
    risky = features.sort_values("risk_score", ascending=False).head(top_n)
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    path = f"{out_path.rstrip('.csv')}_{timestamp}.csv"
    risky.to_csv(path, index=False)
    print(f"Top {top_n} wallets saved to {path}")


def visualize(features: pd.DataFrame):
    import seaborn as sns
    import matplotlib.pyplot as plt
    sns.scatterplot(data=features, x='total_volume_usd', y='risk_score', hue='interacted_with_scam')
    plt.title("Risk Score vs Total Volume (USD)")
    plt.show()


def draw_wallet_graph(df, wallet_address):
    import matplotlib.pyplot as plt
    G = nx.from_pandas_edgelist(df, source='From', target='To', create_using=nx.DiGraph())
    ego = nx.ego_graph(G, wallet_address, radius=2, center=True, undirected=False)

    plt.figure(figsize=(10, 8))
    pos = nx.spring_layout(ego, seed=42)
    nx.draw(ego, pos, with_labels=True, node_color='skyblue', node_size=700, font_size=8, edge_color='gray')
    plt.title(f"Wallet Interaction Graph (radius=2): {wallet_address}")
    plt.show()

# %%
draw_wallet_graph(df, scored.sort_values("risk_score", ascending=False).iloc[0]['From'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1140753325.py in <cell line: 0>()
# ----> 1 draw_wallet_graph(df, scored.sort_values("risk_score", ascending=False).iloc[0]['From'])
#
# NameError: name 'scored' is not defined
